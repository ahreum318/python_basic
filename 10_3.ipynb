# %%
import datetime
import time

# %%
now = datetime.datetime.now()
print(now)
# Out:
# 2026-07-02 13:03:52.418862

# %%
print(now.year)
print(now.month)
print(now.day)
# Out:
# 2026
# 7
# 2

# %%
today = datetime.date.today()
print(today)
# Out:
# 2026-07-02

# %%
weekday = today.weekday()

# if weekday == 0:
#     pass
# elif weekday == 1:
#     pass...
# ㄴ방법이 너무 무식함

week = ["월","화","수","목","금","토","일"] # 0:월

print(week[weekday])

xmas = datetime.date(2026, 12, 25)
print(week[xmas.weekday()])
# Out:
# 목
# 금

# %%
print(xmas - today)
# Out:
# 176 days, 0:00:00

# %%
print(today - datetime.timedelta(days=100))
print(today - datetime)
# Out:
# 2026-03-24
